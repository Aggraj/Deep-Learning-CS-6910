# %% [markdown]
# <a href="https://colab.research.google.com/github/Aggraj/Deep-Learning-CS-6910/blob/main/ffnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class Feedforwardneuralnetwork:

    def __init__(self,n_inputs,n_hidden,n_outputs):

        self.n_inputs   = n_inputs
        self.n_outputs  = n_outputs
        self.n_hidden   = n_hidden
        self.weights    = []
        self.biases     = []

        layers = [self.n_inputs] + self.n_hidden + [self.n_outputs]
        for i in range(len(n_hidden)+1):
            self.weights.append(np.random.randn(layers[i+1],layers[i]))
            self.biases.append(np.random.randn(layers[i+1],1))



    def sigmoid(self,x):
        return 1 / ( 1 + np.exp(-x))

    def softmax(self,x):
        soft = np.zeros(x.shape)
        for i in range(0, x.shape[1]):
            numr = np.exp(x[:, i])
            soft[:, i] = numr/np.sum(numr)
        return soft

    def forward_propagation(self,input):

        self.intermidiate_inputs = []
        self.post_outputs  = []
        W      = self.weights
        b      = self.biases

        k=0
        self.intermidiate_inputs.append(np.matmul(W[k],input)+b[k])
        self.post_outputs.append(self.sigmoid(self.intermidiate_inputs[k]))

        for k in range(1,len(self.n_hidden)):
            self.intermidiate_inputs.append(np.matmul(W[k],self.post_outputs[k-1])+b[k])
            self.post_outputs.append(self.sigmoid(self.intermidiate_inputs[k]))

        k=len(self.n_hidden)
        self.intermidiate_inputs.append(np.matmul(W[k],self.post_outputs[k-1])+b[k])
        self.post_outputs.append(self.softmax(self.intermidiate_inputs[k]))

        return self.post_outputs[-1]

    def back_propagation(self,train_images,train_labels):

        g_weights = [0]*(len(self.weights))
        g_biases  = [0]*(len(self.biases))
        g_a       = [0]*(len(self.n_hidden)+1)
        g_h       = [0]*(len(self.n_hidden)+1)
        n_samples = train_images.shape[0]  # Change depending on the dimensions of data


        for k in reversed(range(len(self.n_hidden)+1)):
            if k == len(self.n_hidden):
                g_a[k] = self.post_outputs[k] - train_labels  # keep or remove T depending on the dimensions of data
                #g_weights[k] = (1/n_samples)*np.matmul(g_a[k],self.post_outputs[k-1].T)
                #g_biases[k]  = (1/n_samples)*np.sum(g_a[k], axis=1, keepdims = True)
            else:
                g_h[k] = (1/n_samples)*np.matmul(self.weights[k+1].T,g_a[k+1])
                g_a[k] = (1/n_samples)*np.multiply(g_h[k],np.multiply(self.sigmoid(self.intermidiate_inputs[k]),(1-self.sigmoid(self.intermidiate_inputs[k]))))

            if k == 0:
                g_weights[k] = (1/n_samples)*np.matmul(g_a[k],train_images.T)
            else:
                g_weights[k] = (1/n_samples)*np.matmul(g_a[k],self.post_outputs[k-1].T)

            g_biases[k]  = (1/n_samples)*np.sum(g_a[k], axis=1, keepdims = True)
        return g_weights,g_biases



    def train_model(self,train_images,train_labels,epochs,learning_rate,opt='gd',gamma = 0.9,beta = 0.99,batch_size = 100): 
         
        pre_delta_w = np.multiply(self.weights,0)
        pre_delta_b = np.multiply(self.biases,0)
        #batch_size = self.batch_size
        vw = 0
        vb = 0
        eps = 1e-8
        lr_w = 0
        lr_b = 0



        for i in range(epochs+1):
          for bb in range(0, train_images.shape[0], batch_size):
            train_b_imag = train_images[:,bb:bb+batch_size]
            train_l_imag = train_labels[:,bb:bb+batch_size]
            output =  self.forward_propagation(train_b_imag)
            g_weights,g_biases = self.back_propagation(train_b_imag,train_l_imag)
            if opt == 'gd':
                delta_w = np.multiply(learning_rate,g_weights)
                delta_b = np.multiply(learning_rate,g_biases)
          
            if opt == 'mgd':
                 delta_w = np.multiply(gamma,pre_delta_w) + np.multiply(learning_rate,g_weights)
                 delta_b = np.multiply(gamma,pre_delta_b) + np.multiply(learning_rate,g_biases)
                 pre_delta_w = delta_w
                 pre_delta_b = delta_b

            if opt == 'ngd':

                self.weights = self.weights - np.multiply(gamma,pre_delta_w)
                self.biases  = self.biases - np.multiply(gamma,pre_delta_b)
                output =  self.forward_propagation(train_b_imag)
                g_weights,g_biases = self.back_propagation(train_b_imag,train_l_imag)

                delta_w = np.multiply(gamma,pre_delta_w) + np.multiply(learning_rate,g_weights)
                delta_b = np.multiply(gamma,pre_delta_b) + np.multiply(learning_rate,g_biases)
                
                pre_delta_w = delta_w
                pre_delta_b = delta_b
                
            if opt == 'Rmsprop': 
                 
                vw = np.multiply(vw,beta) + np.multiply(1-beta,np.power(g_weights,2))
                vb = np.multiply(vb,beta) + np.multiply(1-beta,np.power(g_biases,2))
                lr_w = learning_rate/np.power(vw+eps,1/2)
                lr_b = learning_rate/np.power(vb+eps,1/2)
          
                delta_w = np.multiply(g_weights,lr_w)
                delta_b = np.multiply(g_biases,lr_b)

            self.weights = self.weights - delta_w
            self.biases  = self.biases  - delta_b
            train_loss = -np.sum(np.multiply(train_l_imag,np.log(output)))/train_l_imag.shape[1]    
            #print('training_loss for epoch {} = {}'.format(i,train_loss))

            Validate = Model1.forward_propagation(train_val_images.T)
            out_class=(np.argmax(Validate,axis=0))
            target_class_validate=(np.argmax(train_val_labels,axis=1))
            acc2 = 100*np.sum(out_class==target_class_validate)/Validate.shape[1]
            print('Epoch {}: training_loss = {}, Validation accuracy = {}'.format(i,train_loss,acc2))


        return train_loss

# %%
import tensorflow as tf
from sklearn.metrics import log_loss
from keras.datasets import fashion_mnist
output_classes = 10
Model1  = Feedforwardneuralnetwork(28*28,[64,64],output_classes)
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
n_samples = train_images.shape[0]
train_images = train_images.reshape(n_samples,-1)
train_imag = train_images[:50000,:]
train_val_images = train_images[50000:,:]
labels = np.zeros((train_labels.shape[0],output_classes))
for i in range(train_labels.shape[0]):
  e = [0.0]*output_classes
  e[train_labels[i]] = 1.0
  labels[i] = e
train_label = labels[:50000,:]
train_val_labels = labels[50000:,:]
mean = train_imag.mean(axis=0)
std  = train_imag.std(axis = 0)
train_imag = (train_imag - mean)/std
train_val_images = (train_val_images - mean)/std
epochs = 100
learning_rate = 0.01
#batch_size = 100
(tr_loss) = Model1.train_model(train_imag.T,train_label.T,epochs,learning_rate,'Rmsprop')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:81: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:82: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:123: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:124: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:128: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Epoch 0: training_loss = 7.4555979265956855, Validation accuracy = 12.9
# Epoch 0: training_loss = 5.823365601117594, Validation accuracy = 11.8
# Epoch 0: training_loss = 4.882420935657676, Validation accuracy = 10.86
# Epoch 0: training_loss = 4.2133287657411636, Validation accuracy = 13.33
# Epoch 0: training_loss = 4.399030928581423, Validation accuracy = 11.87
# Epoch 0: training_loss = 4.310497657785628, Validation accuracy = 13.35
# Epoch 0: training_loss = 4.086625230772135, Validation accuracy = 16.52
# Epoch 0: training_loss = 3.7987593584389003, Validation accuracy = 17.43
# Epoch 1: training_loss = 2.982180644195945, Validation accuracy = 17.05
# Epoch 1: training_loss = 3.19968898233292, Validation accuracy = 18.66
# Epoch 1: training_loss = 3.4199123912911453, Validation accuracy = 18.34
# Epoch 1: training_loss = 3.2936528333046, Validation accuracy = 19.61
# Epoch 1: training_loss = 3.2151671839488527, Validation accuracy = 19.82
# Epoch 1: training_loss = 3.2463039226495143, Validation accuracy = 20.73
# Epoch 1: training_loss = 3.055962726070362, Validation accuracy = 22.67
# Epoch 1: training_loss = 2.8965549884083788, Validation accuracy = 24.41
# Epoch 2: training_loss = 2.3305360778585285, Validation accuracy = 24.72
# Epoch 2: training_loss = 2.5586664327061506, Validation accuracy = 25.06
# Epoch 2: training_loss = 2.8845943822399516, Validation accuracy = 25.13
# Epoch 2: training_loss = 2.809085209180677, Validation accuracy = 25.83
# Epoch 2: training_loss = 2.6470729211699666, Validation accuracy = 26.45
# Epoch 2: training_loss = 2.6715740092167954, Validation accuracy = 27.84
# Epoch 2: training_loss = 2.5195362181624024, Validation accuracy = 28.83
# Epoch 2: training_loss = 2.4004574621117563, Validation accuracy = 30.29
# Epoch 3: training_loss = 1.981914479223716, Validation accuracy = 31.06
# Epoch 3: training_loss = 2.1799591215756458, Validation accuracy = 30.83
# Epoch 3: training_loss = 2.5581794783076437, Validation accuracy = 30.84
# Epoch 3: training_loss = 2.512976130013133, Validation accuracy = 30.95
# Epoch 3: training_loss = 2.3020071845337298, Validation accuracy = 31.94
# Epoch 3: training_loss = 2.310550318067956, Validation accuracy = 33.37
# Epoch 3: training_loss = 2.185531752435384, Validation accuracy = 34.4
# Epoch 3: training_loss = 2.0853958917813067, Validation accuracy = 35.18
# Epoch 4: training_loss = 1.7620867163518221, Validation accuracy = 35.68
# Epoch 4: training_loss = 1.931426616042013, Validation accuracy = 35.52
# Epoch 4: training_loss = 2.332544650241486, Validation accuracy = 35.55
# Epoch 4: training_loss = 2.310568350136771, Validation accuracy = 35.82
# Epoch 4: training_loss = 2.071033035275612, Validation accuracy = 36.05
# Epoch 4: training_loss = 2.0666483190659855, Validation accuracy = 37.29
# Epoch 4: training_loss = 1.9586330361326088, Validation accuracy = 38.53
# Epoch 4: training_loss = 1.8688990146764548, Validation accuracy = 39.0
# Epoch 5: training_loss = 1.6090329587607368, Validation accuracy = 39.06
# Epoch 5: training_loss = 1.7559330779478128, Validation accuracy = 39.23
# Epoch 5: training_loss = 2.164342410277112, Validation accuracy = 39.03
# Epoch 5: training_loss = 2.160912640386374, Validation accuracy = 39.32
# Epoch 5: training_loss = 1.9038215611557145, Validation accuracy = 39.32
# Epoch 5: training_loss = 1.8918277109755928, Validation accuracy = 40.27
# Epoch 5: training_loss = 1.794338419936548, Validation accuracy = 41.3
# Epoch 5: training_loss = 1.7111164753730999, Validation accuracy = 41.68
# Epoch 6: training_loss = 1.494605516690812, Validation accuracy = 41.83
# Epoch 6: training_loss = 1.6252707909464505, Validation accuracy = 41.99
# Epoch 6: training_loss = 2.0324285344483535, Validation accuracy = 41.62
# Epoch 6: training_loss = 2.0443554657768597, Validation accuracy = 41.75
# Epoch 6: training_loss = 1.7761446092044215, Validation accuracy = 41.87
# Epoch 6: training_loss = 1.7606354492061536, Validation accuracy = 42.7
# Epoch 6: training_loss = 1.6697015081776678, Validation accuracy = 43.8
# Epoch 6: training_loss = 1.590951416654008, Validation accuracy = 44.06
# Epoch 7: training_loss = 1.4046721634947905, Validation accuracy = 43.8
# Epoch 7: training_loss = 1.5244347484411902, Validation accuracy = 44.3
# Epoch 7: training_loss = 1.925255889117372, Validation accuracy = 44.01
# Epoch 7: training_loss = 1.9502111324176417, Validation accuracy = 43.81
# Epoch 7: training_loss = 1.6749818287373115, Validation accuracy = 43.78
# Epoch 7: training_loss = 1.6585698538264877, Validation accuracy = 44.55
# Epoch 7: training_loss = 1.5718365433702368, Validation accuracy = 45.74
# Epoch 7: training_loss = 1.496327533613319, Validation accuracy = 45.63
# Epoch 8: training_loss = 1.331436153639748, Validation accuracy = 45.47
# Epoch 8: training_loss = 1.4445791539642994, Validation accuracy = 46.18
# Epoch 8: training_loss = 1.8358956221515796, Validation accuracy = 45.76
# Epoch 8: training_loss = 1.871980856408821, Validation accuracy = 45.29
# Epoch 8: training_loss = 1.5925389656698388, Validation accuracy = 45.43
# Epoch 8: training_loss = 1.5768141972031764, Validation accuracy = 46.2
# Epoch 8: training_loss = 1.4929436707738655, Validation accuracy = 47.14
# Epoch 8: training_loss = 1.4198133216911009, Validation accuracy = 47.12
# Epoch 9: training_loss = 1.2702403345328244, Validation accuracy = 46.92
# Epoch 9: training_loss = 1.379994693316274, Validation accuracy = 47.63
# Epoch 9: training_loss = 1.7598757908100016, Validation accuracy = 47.09
# Epoch 9: training_loss = 1.8054185220844665, Validation accuracy = 46.82
# Epoch 9: training_loss = 1.523809772000203, Validation accuracy = 46.86
# Epoch 9: training_loss = 1.5097118247300616, Validation accuracy = 47.65
# Epoch 9: training_loss = 1.4279926701098065, Validation accuracy = 48.54
# Epoch 9: training_loss = 1.3565510030109817, Validation accuracy = 48.19
# Epoch 10: training_loss = 1.218098510692125, Validation accuracy = 48.25
# Epoch 10: training_loss = 1.3267577061822795, Validation accuracy = 48.8
# Epoch 10: training_loss = 1.6941620196816232, Validation accuracy = 48.37
# Epoch 10: training_loss = 1.747636265156089, Validation accuracy = 48.07
# Epoch 10: training_loss = 1.4654276029733644, Validation accuracy = 48.05
# Epoch 10: training_loss = 1.4534739667615804, Validation accuracy = 48.76
# Epoch 10: training_loss = 1.3735649543186423, Validation accuracy = 49.72
# Epoch 10: training_loss = 1.3032197067992433, Validation accuracy = 49.4
# Epoch 11: training_loss = 1.1729777847071012, Validation accuracy = 49.31
# Epoch 11: training_loss = 1.2820805744512498, Validation accuracy = 49.65
# Epoch 11: training_loss = 1.6366125208712268, Validation accuracy = 49.4
# Epoch 11: training_loss = 1.6966226734917234, Validation accuracy = 49.19
# Epoch 11: training_loss = 1.4150449342568285, Validation accuracy = 49.27
# Epoch 11: training_loss = 1.405477695583723, Validation accuracy = 49.88
# Epoch 11: training_loss = 1.3272442495087466, Validation accuracy = 50.56
# Epoch 11: training_loss = 1.2574851724048524, Validation accuracy = 50.26
# Epoch 12: training_loss = 1.133430661371205, Validation accuracy = 50.24
# Epoch 12: training_loss = 1.2439550558523975, Validation accuracy = 50.54
# Epoch 12: training_loss = 1.585661138390779, Validation accuracy = 50.38
# Epoch 12: training_loss = 1.6509516597172131, Validation accuracy = 50.05
# Epoch 12: training_loss = 1.3709732888998423, Validation accuracy = 50.31
# Epoch 12: training_loss = 1.363860397799528, Validation accuracy = 50.74
# Epoch 12: training_loss = 1.2872750082505087, Validation accuracy = 51.52
# Epoch 12: training_loss = 1.2176785309354567, Validation accuracy = 51.06
# Epoch 13: training_loss = 1.0983927819394004, Validation accuracy = 51.04
# Epoch 13: training_loss = 1.2109232611019578, Validation accuracy = 51.27
# Epoch 13: training_loss = 1.5401271783136783, Validation accuracy = 51.04
# Epoch 13: training_loss = 1.6095941985455793, Validation accuracy = 50.89
# Epoch 13: training_loss = 1.3319659680936058, Validation accuracy = 51.07
# Epoch 13: training_loss = 1.3272713687547164, Validation accuracy = 51.41
# Epoch 13: training_loss = 1.252356110480524, Validation accuracy = 52.4
# Epoch 13: training_loss = 1.1825894530539316, Validation accuracy = 51.95
# Epoch 14: training_loss = 1.0670626621871322, Validation accuracy = 51.65
# Epoch 14: training_loss = 1.1819174522425069, Validation accuracy = 51.99
# Epoch 14: training_loss = 1.499099065631578, Validation accuracy = 51.92
# Epoch 14: training_loss = 1.5717931218886019, Validation accuracy = 51.45
# Epoch 14: training_loss = 1.2970822083694535, Validation accuracy = 51.72
# Epoch 14: training_loss = 1.29471262069067, Validation accuracy = 52.11
# Epoch 14: training_loss = 1.2215080432254162, Validation accuracy = 53.05
# Epoch 14: training_loss = 1.1513261940614965, Validation accuracy = 52.62
# Epoch 15: training_loss = 1.0388252014467907, Validation accuracy = 52.37
# Epoch 15: training_loss = 1.1561464965684372, Validation accuracy = 52.65
# Epoch 15: training_loss = 1.4618606458996848, Validation accuracy = 52.63
# Epoch 15: training_loss = 1.5369793160861542, Validation accuracy = 52.1
# Epoch 15: training_loss = 1.2655991830057112, Validation accuracy = 52.45
# Epoch 15: training_loss = 1.2654338689475686, Validation accuracy = 52.77
# Epoch 15: training_loss = 1.193983490394615, Validation accuracy = 53.71
# Epoch 15: training_loss = 1.1232200361747384, Validation accuracy = 53.14
# Epoch 16: training_loss = 1.0132005351805422, Validation accuracy = 53.01
# Epoch 16: training_loss = 1.1330161788257131, Validation accuracy = 53.24
# Epoch 16: training_loss = 1.4278421273807664, Validation accuracy = 53.35
# Epoch 16: training_loss = 1.5047155695532775, Validation accuracy = 52.62
# Epoch 16: training_loss = 1.2369531079814606, Validation accuracy = 52.95
# Epoch 16: training_loss = 1.2388619490163704, Validation accuracy = 53.29
# Epoch 16: training_loss = 1.1692053529922466, Validation accuracy = 54.2
# Epoch 16: training_loss = 1.0977601505524723, Validation accuracy = 53.6
# Epoch 17: training_loss = 0.9898086579941778, Validation accuracy = 53.59
# Epoch 17: training_loss = 1.112073662487057, Validation accuracy = 53.75
# Epoch 17: training_loss = 1.3965857293098003, Validation accuracy = 53.88
# Epoch 17: training_loss = 1.4746588324427845, Validation accuracy = 53.16
# Epoch 17: training_loss = 1.2106986598148746, Validation accuracy = 53.54
# Epoch 17: training_loss = 1.2145526243841565, Validation accuracy = 53.79
# Epoch 17: training_loss = 1.1467229012634919, Validation accuracy = 54.67
# Epoch 17: training_loss = 1.0745490854405426, Validation accuracy = 54.01
# Epoch 18: training_loss = 0.9683444197188511, Validation accuracy = 54.15
# Epoch 18: training_loss = 1.0929687611001528, Validation accuracy = 54.33
# Epoch 18: training_loss = 1.3677206223116434, Validation accuracy = 54.41
# Epoch 18: training_loss = 1.4465346792907445, Validation accuracy = 53.71
# Epoch 18: training_loss = 1.186480273250914, Validation accuracy = 54.26
# Epoch 18: training_loss = 1.1921571333841319, Validation accuracy = 54.32
# Epoch 18: training_loss = 1.1261802742475964, Validation accuracy = 55.18
# Epoch 18: training_loss = 1.0532720957956325, Validation accuracy = 54.37
# Epoch 19: training_loss = 0.9485596054647254, Validation accuracy = 54.52
# Epoch 19: training_loss = 1.0754267660612329, Validation accuracy = 54.78
# Epoch 19: training_loss = 1.3409441180281438, Validation accuracy = 54.76
# Epoch 19: training_loss = 1.4201198375780177, Validation accuracy = 54.06
# Epoch 19: training_loss = 1.1640113724543324, Validation accuracy = 54.64
# Epoch 19: training_loss = 1.1713985469593673, Validation accuracy = 54.76
# Epoch 19: training_loss = 1.1072935673242272, Validation accuracy = 55.58
# Epoch 19: training_loss = 1.033675767130909, Validation accuracy = 54.78
# Epoch 20: training_loss = 0.9302499629814488, Validation accuracy = 54.99
# Epoch 20: training_loss = 1.0592291990802511, Validation accuracy = 55.19
# Epoch 20: training_loss = 1.316007289466899, Validation accuracy = 55.19
# Epoch 20: training_loss = 1.3952300424552828, Validation accuracy = 54.5
# Epoch 20: training_loss = 1.1430590492613244, Validation accuracy = 54.93
# Epoch 20: training_loss = 1.1520547484153045, Validation accuracy = 55.15
# Epoch 20: training_loss = 1.0898339904858516, Validation accuracy = 55.86
# Epoch 20: training_loss = 1.0155529325513697, Validation accuracy = 55.15
# Epoch 21: training_loss = 0.9132457206422608, Validation accuracy = 55.36
# Epoch 21: training_loss = 1.0442000160112812, Validation accuracy = 55.56
# Epoch 21: training_loss = 1.292703855000314, Validation accuracy = 55.61
# Epoch 21: training_loss = 1.3717114131077508, Validation accuracy = 54.86
# Epoch 21: training_loss = 1.1234325782675936, Validation accuracy = 55.31
# Epoch 21: training_loss = 1.1339459563146717, Validation accuracy = 55.46
# Epoch 21: training_loss = 1.0736153738514553, Validation accuracy = 56.29
# Epoch 21: training_loss = 0.9987318953238412, Validation accuracy = 55.42
# Epoch 22: training_loss = 0.8974045684954882, Validation accuracy = 55.72
# Epoch 22: training_loss = 1.0301955843473736, Validation accuracy = 55.96
# Epoch 22: training_loss = 1.2708615267315644, Validation accuracy = 56.05
# Epoch 22: training_loss = 1.3494341691838947, Validation accuracy = 55.29
# Epoch 22: training_loss = 1.1049746954630109, Validation accuracy = 55.67
# Epoch 22: training_loss = 1.1169254189313065, Validation accuracy = 55.75
# Epoch 22: training_loss = 1.0584848196018697, Validation accuracy = 56.55
# Epoch 22: training_loss = 0.983068623266847, Validation accuracy = 55.78
# Epoch 23: training_loss = 0.8826063640780287, Validation accuracy = 55.94
# Epoch 23: training_loss = 1.0170972963126028, Validation accuracy = 56.14
# Epoch 23: training_loss = 1.2503352469134423, Validation accuracy = 56.39
# Epoch 23: training_loss = 1.3282879179263443, Validation accuracy = 55.65
# Epoch 23: training_loss = 1.0875549035709693, Validation accuracy = 55.95
# Epoch 23: training_loss = 1.1008723623557934, Validation accuracy = 56.09
# Epoch 23: training_loss = 1.0443156518621646, Validation accuracy = 56.66
# Epoch 23: training_loss = 0.968441008719183, Validation accuracy = 56.1
# Epoch 24: training_loss = 0.8687490329674924, Validation accuracy = 56.22
# Epoch 24: training_loss = 1.0048060453031895, Validation accuracy = 56.25
# Epoch 24: training_loss = 1.231001881211001, Validation accuracy = 56.77
# Epoch 24: training_loss = 1.3081780138126613, Validation accuracy = 55.91
# Epoch 24: training_loss = 1.0710642832083754, Validation accuracy = 56.2
# Epoch 24: training_loss = 1.085686569437091, Validation accuracy = 56.37
# Epoch 24: training_loss = 1.0310020579633956, Validation accuracy = 57.01
# Epoch 24: training_loss = 0.9547445744632631, Validation accuracy = 56.44
# Epoch 25: training_loss = 0.8557452922760344, Validation accuracy = 56.48
# Epoch 25: training_loss = 0.9932380420406034, Validation accuracy = 56.59
# Epoch 25: training_loss = 1.2127560385045986, Validation accuracy = 56.96
# Epoch 25: training_loss = 1.2890226705914603, Validation accuracy = 56.28
# Epoch 25: training_loss = 1.0554114316374905, Validation accuracy = 56.52
# Epoch 25: training_loss = 1.0712841617907736, Validation accuracy = 56.55
# Epoch 25: training_loss = 1.0184549828755898, Validation accuracy = 57.3
# Epoch 25: training_loss = 0.9418892024454673, Validation accuracy = 56.64
# Epoch 26: training_loss = 0.8435199488599722, Validation accuracy = 56.81
# Epoch 26: training_loss = 0.982321615665966, Validation accuracy = 56.89
# Epoch 26: training_loss = 1.195506761394804, Validation accuracy = 57.19
# Epoch 26: training_loss = 1.2707506226948084, Validation accuracy = 56.56
# Epoch 26: training_loss = 1.04051924882849, Validation accuracy = 56.77
# Epoch 26: training_loss = 1.057594287839127, Validation accuracy = 56.77
# Epoch 26: training_loss = 1.0065989570250418, Validation accuracy = 57.7
# Epoch 26: training_loss = 0.9297965979342061, Validation accuracy = 56.86
# Epoch 27: training_loss = 0.8320076201850941, Validation accuracy = 57.18
# Epoch 27: training_loss = 0.9719947586075005, Validation accuracy = 57.06
# Epoch 27: training_loss = 1.1791748892836136, Validation accuracy = 57.48
# Epoch 27: training_loss = 1.2532992096758284, Validation accuracy = 56.73
# Epoch 27: training_loss = 1.0263223612966186, Validation accuracy = 57.04
# Epoch 27: training_loss = 1.0445565082299118, Validation accuracy = 56.96
# Epoch 27: training_loss = 0.9953696218970101, Validation accuracy = 57.94
# Epoch 27: training_loss = 0.9183982947569185, Validation accuracy = 57.07
# Epoch 28: training_loss = 0.8211507976190567, Validation accuracy = 57.38
# Epoch 28: training_loss = 0.962203248424356, Validation accuracy = 57.38
# Epoch 28: training_loss = 1.1636909422293513, Validation accuracy = 57.67
# Epoch 28: training_loss = 1.2366128061542663, Validation accuracy = 57.01
# Epoch 28: training_loss = 1.0127650281499012, Validation accuracy = 57.32
# Epoch 28: training_loss = 1.0321187296429857, Validation accuracy = 57.14
# Epoch 28: training_loss = 0.9847117785613184, Validation accuracy = 58.09
# Epoch 28: training_loss = 0.9076340693106302, Validation accuracy = 57.27
# Epoch 29: training_loss = 0.8108982203600706, Validation accuracy = 57.5
# Epoch 29: training_loss = 0.9528992258926212, Validation accuracy = 57.59
# Epoch 29: training_loss = 1.1489934115845626, Validation accuracy = 57.93
# Epoch 29: training_loss = 1.2206415484282416, Validation accuracy = 57.11
# Epoch 29: training_loss = 0.9997994166513233, Validation accuracy = 57.51
# Epoch 29: training_loss = 1.0202355775727312, Validation accuracy = 57.24
# Epoch 29: training_loss = 0.9745778290207073, Validation accuracy = 58.29
# Epoch 29: training_loss = 0.8974506708783274, Validation accuracy = 57.49
# Epoch 30: training_loss = 0.8012035537195977, Validation accuracy = 57.79
# Epoch 30: training_loss = 0.9440401347013201, Validation accuracy = 57.76
# Epoch 30: training_loss = 1.1350273740244345, Validation accuracy = 58.19
# Epoch 30: training_loss = 1.2053403226581643, Validation accuracy = 57.49
# Epoch 30: training_loss = 0.9873841688200992, Validation accuracy = 57.67
# Epoch 30: training_loss = 1.0088671240165226, Validation accuracy = 57.46
# Epoch 30: training_loss = 0.96492651411813, Validation accuracy = 58.42
# Epoch 30: training_loss = 0.8878008003609617, Validation accuracy = 57.71
# Epoch 31: training_loss = 0.7920243699716965, Validation accuracy = 57.91
# Epoch 31: training_loss = 0.9355879416804913, Validation accuracy = 58.01
# Epoch 31: training_loss = 1.1217433692404768, Validation accuracy = 58.41
# Epoch 31: training_loss = 1.1906679828790079, Validation accuracy = 57.65
# Epoch 31: training_loss = 0.9754832067225638, Validation accuracy = 57.84
# Epoch 31: training_loss = 0.9979779016286366, Validation accuracy = 57.72
# Epoch 31: training_loss = 0.9557218778119079, Validation accuracy = 58.68
# Epoch 31: training_loss = 0.8786422845168719, Validation accuracy = 57.94
# Epoch 32: training_loss = 0.783321418413493, Validation accuracy = 58.11
# Epoch 32: training_loss = 0.9275085643771718, Validation accuracy = 58.12
# Epoch 32: training_loss = 1.109096498221828, Validation accuracy = 58.58
# Epoch 32: training_loss = 1.1765867646652552, Validation accuracy = 57.83
# Epoch 32: training_loss = 0.9640647420563844, Validation accuracy = 58.01
# Epoch 32: training_loss = 0.9875361457304492, Validation accuracy = 57.97
# Epoch 32: training_loss = 0.9469324077026121, Validation accuracy = 58.93
# Epoch 32: training_loss = 0.8699374025847735, Validation accuracy = 58.12
# Epoch 33: training_loss = 0.775058151670782, Validation accuracy = 58.35
# Epoch 33: training_loss = 0.9197714406259206, Validation accuracy = 58.29
# Epoch 33: training_loss = 1.0970457089765242, Validation accuracy = 58.78
# Epoch 33: training_loss = 1.1630618565360298, Validation accuracy = 57.99
# Epoch 33: training_loss = 0.9531004658110334, Validation accuracy = 58.17
# Epoch 33: training_loss = 0.9775132129056572, Validation accuracy = 58.13
# Epoch 33: training_loss = 0.9385303166906188, Validation accuracy = 59.18
# Epoch 33: training_loss = 0.8616523297522215, Validation accuracy = 58.3
# Epoch 34: training_loss = 0.7672004567198024, Validation accuracy = 58.63
# Epoch 34: training_loss = 0.9123491856575536, Validation accuracy = 58.51
# Epoch 34: training_loss = 1.0855532410034343, Validation accuracy = 59.02
# Epoch 34: training_loss = 1.1500610896279897, Validation accuracy = 58.06
# Epoch 34: training_loss = 0.9425648976616696, Validation accuracy = 58.32
# Epoch 34: training_loss = 0.9678831320351603, Validation accuracy = 58.33
# Epoch 34: training_loss = 0.9304909411751439, Validation accuracy = 59.46
# Epoch 34: training_loss = 0.8537566688970386, Validation accuracy = 58.59
# Epoch 35: training_loss = 0.759716528686933, Validation accuracy = 58.89
# Epoch 35: training_loss = 0.9052172963952185, Validation accuracy = 58.73
# Epoch 35: training_loss = 1.0745842009645976, Validation accuracy = 59.18
# Epoch 35: training_loss = 1.1375547084754432, Validation accuracy = 58.28
# Epoch 35: training_loss = 0.9324348747153117, Validation accuracy = 58.64
# Epoch 35: training_loss = 0.9586222514873639, Validation accuracy = 58.49
# Epoch 35: training_loss = 0.9227922379774828, Validation accuracy = 59.62
# Epoch 35: training_loss = 0.8462230487768452, Validation accuracy = 58.77
# Epoch 36: training_loss = 0.7525768261005128, Validation accuracy = 59.05
# Epoch 36: training_loss = 0.8983538777719551, Validation accuracy = 58.85
# Epoch 36: training_loss = 1.0641062422384056, Validation accuracy = 59.3
# Epoch 36: training_loss = 1.1255151916931652, Validation accuracy = 58.47
# Epoch 36: training_loss = 0.9226891578709003, Validation accuracy = 58.8
# Epoch 36: training_loss = 0.9497089545306562, Validation accuracy = 58.6
# Epoch 36: training_loss = 0.9154143660943878, Validation accuracy = 59.81
# Epoch 36: training_loss = 0.8390267730708161, Validation accuracy = 58.9
# Epoch 37: training_loss = 0.7457540563561232, Validation accuracy = 59.23
# Epoch 37: training_loss = 0.8917393793425126, Validation accuracy = 59.05
# Epoch 37: training_loss = 1.0540893221918695, Validation accuracy = 59.56
# Epoch 37: training_loss = 1.113917099417117, Validation accuracy = 58.7
# Epoch 37: training_loss = 0.9133081333626717, Validation accuracy = 58.89
# Epoch 37: training_loss = 0.9411234229967909, Validation accuracy = 58.82
# Epoch 37: training_loss = 0.9083393414673964, Validation accuracy = 59.95
# Epoch 37: training_loss = 0.8321455098979397, Validation accuracy = 59.01
# Epoch 38: training_loss = 0.7392231554665184, Validation accuracy = 59.35
# Epoch 38: training_loss = 0.8853563401184584, Validation accuracy = 59.15
# Epoch 38: training_loss = 1.0445055138591917, Validation accuracy = 59.7
# Epoch 38: training_loss = 1.1027369326245542, Validation accuracy = 58.71
# Epoch 38: training_loss = 0.9042735879660886, Validation accuracy = 59.05
# Epoch 38: training_loss = 0.932847435926264, Validation accuracy = 58.93
# Epoch 38: training_loss = 0.9015507540858013, Validation accuracy = 60.01
# Epoch 38: training_loss = 0.8255590153273935, Validation accuracy = 59.13
# Epoch 39: training_loss = 0.7329612420697975, Validation accuracy = 59.4
# Epoch 39: training_loss = 0.8791891448590795, Validation accuracy = 59.35
# Epoch 39: training_loss = 1.0353288530090865, Validation accuracy = 59.8
# Epoch 39: training_loss = 1.0919529964588695, Validation accuracy = 58.85
# Epoch 39: training_loss = 0.8955685388232197, Validation accuracy = 59.2
# Epoch 39: training_loss = 0.9248641949091815, Validation accuracy = 59.19
# Epoch 39: training_loss = 0.8950335375599073, Validation accuracy = 60.08
# Epoch 39: training_loss = 0.819248886936261, Validation accuracy = 59.22
# Epoch 40: training_loss = 0.7269475388430854, Validation accuracy = 59.55
# Epoch 40: training_loss = 0.8732237966948752, Validation accuracy = 59.56
# Epoch 40: training_loss = 1.026535206521375, Validation accuracy = 59.85
# Epoch 40: training_loss = 1.081545264719529, Validation accuracy = 58.95
# Epoch 40: training_loss = 0.8871771022882949, Validation accuracy = 59.39
# Epoch 40: training_loss = 0.9171581711130394, Validation accuracy = 59.43
# Epoch 40: training_loss = 0.8887737821481556, Validation accuracy = 60.27
# Epoch 40: training_loss = 0.8131983448770871, Validation accuracy = 59.15
# Epoch 41: training_loss = 0.7211632634553534, Validation accuracy = 59.65
# Epoch 41: training_loss = 0.8674477102515263, Validation accuracy = 59.69
# Epoch 41: training_loss = 1.0181021527155731, Validation accuracy = 60.0
# Epoch 41: training_loss = 1.071495245722732, Validation accuracy = 59.05
# Epoch 41: training_loss = 0.8790843898784629, Validation accuracy = 59.48
# Epoch 41: training_loss = 0.9097149708946484, Validation accuracy = 59.58
# Epoch 41: training_loss = 0.8827585832040984, Validation accuracy = 60.28
# Epoch 41: training_loss = 0.8073920385242892, Validation accuracy = 59.22
# Epoch 42: training_loss = 0.7155914960644251, Validation accuracy = 59.75
# Epoch 42: training_loss = 0.8618495276741875, Validation accuracy = 59.82
# Epoch 42: training_loss = 1.0100088681863155, Validation accuracy = 60.19
# Epoch 42: training_loss = 1.061785851183308, Validation accuracy = 59.3
# Epoch 42: training_loss = 0.8712764227776253, Validation accuracy = 59.57
# Epoch 42: training_loss = 0.9025212178649631, Validation accuracy = 59.65
# Epoch 42: training_loss = 0.8769759180975483, Validation accuracy = 60.32
# Epoch 42: training_loss = 0.8018158769011248, Validation accuracy = 59.28
# Epoch 43: training_loss = 0.710217032038169, Validation accuracy = 59.77
# Epoch 43: training_loss = 0.8564189580582471, Validation accuracy = 59.88
# Epoch 43: training_loss = 1.0022360185583126, Validation accuracy = 60.36
# Epoch 43: training_loss = 1.052401270133993, Validation accuracy = 59.41
# Epoch 43: training_loss = 0.8637400590818521, Validation accuracy = 59.76
# Epoch 43: training_loss = 0.895564449703834, Validation accuracy = 59.78
# Epoch 43: training_loss = 0.8714145457772565, Validation accuracy = 60.44
# Epoch 43: training_loss = 0.7964568810039109, Validation accuracy = 59.39
# Epoch 44: training_loss = 0.7050262282049877, Validation accuracy = 59.83
# Epoch 44: training_loss = 0.8511466392753653, Validation accuracy = 59.99
# Epoch 44: training_loss = 0.9947656524133079, Validation accuracy = 60.43
# Epoch 44: training_loss = 1.0433268496565191, Validation accuracy = 59.53
# Epoch 44: training_loss = 0.8564629300196396, Validation accuracy = 59.82
# Epoch 44: training_loss = 0.8888330281862293, Validation accuracy = 59.88
# Epoch 44: training_loss = 0.8660639242003293, Validation accuracy = 60.48
# Epoch 44: training_loss = 0.7913030560050801, Validation accuracy = 59.45
# Epoch 45: training_loss = 0.7000068495123065, Validation accuracy = 59.81
# Epoch 45: training_loss = 0.8460240202051369, Validation accuracy = 60.03
# Epoch 45: training_loss = 0.9875810986554221, Validation accuracy = 60.43
# Epoch 45: training_loss = 1.0345489836958524, Validation accuracy = 59.63
# Epoch 45: training_loss = 0.8494333827981229, Validation accuracy = 59.98
# Epoch 45: training_loss = 0.88231606094935, Validation accuracy = 59.99
# Epoch 45: training_loss = 0.8609141418012729, Validation accuracy = 60.63
# Epoch 45: training_loss = 0.7863432812220001, Validation accuracy = 59.47
# Epoch 46: training_loss = 0.6951479212002342, Validation accuracy = 59.99
# Epoch 46: training_loss = 0.8410432609040731, Validation accuracy = 60.26
# Epoch 46: training_loss = 0.9806668680093692, Validation accuracy = 60.43
# Epoch 46: training_loss = 1.0260550106795008, Validation accuracy = 59.76
# Epoch 46: training_loss = 0.8426404286484817, Validation accuracy = 60.05
# Epoch 46: training_loss = 0.8760033335843832, Validation accuracy = 60.12
# Epoch 46: training_loss = 0.8559558599842865, Validation accuracy = 60.65
# Epoch 46: training_loss = 0.7815672157200747, Validation accuracy = 59.56
# Epoch 47: training_loss = 0.6904395898995879, Validation accuracy = 60.03
# Epoch 47: training_loss = 0.8361971481406998, Validation accuracy = 60.42
# Epoch 47: training_loss = 0.9740085594078746, Validation accuracy = 60.54
# Epoch 47: training_loss = 1.0178331201798545, Validation accuracy = 59.88
# Epoch 47: training_loss = 0.8360736952087636, Validation accuracy = 60.14
# Epoch 47: training_loss = 0.8698852507086738, Validation accuracy = 60.29
# Epoch 47: training_loss = 0.8511802642916783, Validation accuracy = 60.7
# Epoch 47: training_loss = 0.776965217479445, Validation accuracy = 59.66
# Epoch 48: training_loss = 0.6858729956383022, Validation accuracy = 60.15
# Epoch 48: training_loss = 0.8314790238624248, Validation accuracy = 60.51
# Epoch 48: training_loss = 0.967592771890204, Validation accuracy = 60.61
# Epoch 48: training_loss = 1.0098722684825676, Validation accuracy = 60.0
# Epoch 48: training_loss = 0.8297233827087177, Validation accuracy = 60.24
# Epoch 48: training_loss = 0.8639527847690078, Validation accuracy = 60.39
# Epoch 48: training_loss = 0.8465790224389635, Validation accuracy = 60.82
# Epoch 48: training_loss = 0.7725282741807399, Validation accuracy = 59.78
# Epoch 49: training_loss = 0.6814401556466312, Validation accuracy = 60.24
# Epoch 49: training_loss = 0.8268827244235769, Validation accuracy = 60.56
# Epoch 49: training_loss = 0.961407022418976, Validation accuracy = 60.62
# Epoch 49: training_loss = 1.0021621026624126, Validation accuracy = 60.07
# Epoch 49: training_loss = 0.823580223598488, Validation accuracy = 60.3
# Epoch 49: training_loss = 0.8581974314387019, Validation accuracy = 60.43
# Epoch 49: training_loss = 0.8421442478301765, Validation accuracy = 60.87
# Epoch 49: training_loss = 0.768247943837145, Validation accuracy = 59.88
# Epoch 50: training_loss = 0.677133860071445, Validation accuracy = 60.33
# Epoch 50: training_loss = 0.822402528714946, Validation accuracy = 60.63
# Epoch 50: training_loss = 0.9554396697977264, Validation accuracy = 60.64
# Epoch 50: training_loss = 0.9946928926053928, Validation accuracy = 60.14
# Epoch 50: training_loss = 0.8176354453529752, Validation accuracy = 60.32
# Epoch 50: training_loss = 0.8526111705922879, Validation accuracy = 60.51
# Epoch 50: training_loss = 0.8378684674943422, Validation accuracy = 60.97
# Epoch 50: training_loss = 0.7641163036977703, Validation accuracy = 59.92
# Epoch 51: training_loss = 0.6729475791919168, Validation accuracy = 60.45
# Epoch 51: training_loss = 0.8180331136438133, Validation accuracy = 60.71
# Epoch 51: training_loss = 0.9496798446741955, Validation accuracy = 60.65
# Epoch 51: training_loss = 0.9874554703313003, Validation accuracy = 60.18
# Epoch 51: training_loss = 0.8118807362262811, Validation accuracy = 60.47
# Epoch 51: training_loss = 0.847186431964507, Validation accuracy = 60.59
# Epoch 51: training_loss = 0.8337445936342399, Validation accuracy = 60.96
# Epoch 51: training_loss = 0.76012590605399, Validation accuracy = 59.94
# Epoch 52: training_loss = 0.6688753814134408, Validation accuracy = 60.59
# Epoch 52: training_loss = 0.8137695156934852, Validation accuracy = 60.77
# Epoch 52: training_loss = 0.9441173854591355, Validation accuracy = 60.83
# Epoch 52: training_loss = 0.9804411759432721, Validation accuracy = 60.27
# Epoch 52: training_loss = 0.8063082137499223, Validation accuracy = 60.47
# Epoch 52: training_loss = 0.8419160647199775, Validation accuracy = 60.77
# Epoch 52: training_loss = 0.8297658981678293, Validation accuracy = 61.03
# Epoch 52: training_loss = 0.7562697397831554, Validation accuracy = 59.99
# Epoch 53: training_loss = 0.664911861148801, Validation accuracy = 60.54
# Epoch 53: training_loss = 0.8096070975317454, Validation accuracy = 60.84
# Epoch 53: training_loss = 0.9387427798798279, Validation accuracy = 60.92
# Epoch 53: training_loss = 0.9736418095421767, Validation accuracy = 60.38
# Epoch 53: training_loss = 0.8009103957779512, Validation accuracy = 60.5
# Epoch 53: training_loss = 0.8367933102726988, Validation accuracy = 60.78
# Epoch 53: training_loss = 0.8259259897844953, Validation accuracy = 61.02
# Epoch 53: training_loss = 0.7525411966536106, Validation accuracy = 60.12
# Epoch 54: training_loss = 0.661052075629945, Validation accuracy = 60.52
# Epoch 54: training_loss = 0.8055415188366942, Validation accuracy = 60.91
# Epoch 54: training_loss = 0.9335471118170061, Validation accuracy = 60.93
# Epoch 54: training_loss = 0.9670495884794624, Validation accuracy = 60.47
# Epoch 54: training_loss = 0.7956801738887875, Validation accuracy = 60.58
# Epoch 54: training_loss = 0.831811777798505, Validation accuracy = 60.81
# Epoch 54: training_loss = 0.822218793143791, Validation accuracy = 61.03
# Epoch 54: training_loss = 0.748934041585721, Validation accuracy = 60.17
# Epoch 55: training_loss = 0.657291489695296, Validation accuracy = 60.53
# Epoch 55: training_loss = 0.8015687106692212, Validation accuracy = 60.96
# Epoch 55: training_loss = 0.9285220130361174, Validation accuracy = 60.97
# Epoch 55: training_loss = 0.9606571093715557, Validation accuracy = 60.49
# Epoch 55: training_loss = 0.7906107889604957, Validation accuracy = 60.69
# Epoch 55: training_loss = 0.8269654219774634, Validation accuracy = 60.84
# Epoch 55: training_loss = 0.8186385299223595, Validation accuracy = 61.05
# Epoch 55: training_loss = 0.7454423862125791, Validation accuracy = 60.3
# Epoch 56: training_loss = 0.65362592764052, Validation accuracy = 60.63
# Epoch 56: training_loss = 0.7976848528492616, Validation accuracy = 61.06
# Epoch 56: training_loss = 0.9236596194110643, Validation accuracy = 60.99
# Epoch 56: training_loss = 0.9544573143544817, Validation accuracy = 60.5
# Epoch 56: training_loss = 0.7856958087444977, Validation accuracy = 60.76
# Epoch 56: training_loss = 0.8222485225865717, Validation accuracy = 60.98
# Epoch 56: training_loss = 0.8151797014721498, Validation accuracy = 61.1
# Epoch 56: training_loss = 0.7420606652106155, Validation accuracy = 60.39
# Epoch 57: training_loss = 0.6500515312869857, Validation accuracy = 60.62
# Epoch 57: training_loss = 0.7938863538936252, Validation accuracy = 61.07
# Epoch 57: training_loss = 0.9189525312435677, Validation accuracy = 61.04
# Epoch 57: training_loss = 0.948443461113737, Validation accuracy = 60.51
# Epoch 57: training_loss = 0.7809291072723193, Validation accuracy = 60.78
# Epoch 57: training_loss = 0.8176556656359165, Validation accuracy = 61.02
# Epoch 57: training_loss = 0.811837072895402, Validation accuracy = 61.23
# Epoch 57: training_loss = 0.7387836149751437, Validation accuracy = 60.53
# Epoch 58: training_loss = 0.6465647234993744, Validation accuracy = 60.71
# Epoch 58: training_loss = 0.7901698331521578, Validation accuracy = 61.14
# Epoch 58: training_loss = 0.9143937772981203, Validation accuracy = 61.09
# Epoch 58: training_loss = 0.9426090962782899, Validation accuracy = 60.55
# Epoch 58: training_loss = 0.7763048459404538, Validation accuracy = 60.83
# Epoch 58: training_loss = 0.8131817258038823, Validation accuracy = 61.01
# Epoch 58: training_loss = 0.808605658373277, Validation accuracy = 61.24
# Epoch 58: training_loss = 0.735606254300788, Validation accuracy = 60.59
# Epoch 59: training_loss = 0.643162176463987, Validation accuracy = 60.79
# Epoch 59: training_loss = 0.7865321048409192, Validation accuracy = 61.13
# Epoch 59: training_loss = 0.909976782196487, Validation accuracy = 61.15
# Epoch 59: training_loss = 0.9369480318169431, Validation accuracy = 60.61
# Epoch 59: training_loss = 0.7718174561293182, Validation accuracy = 60.8
# Epoch 59: training_loss = 0.8088218499797566, Validation accuracy = 61.08
# Epoch 59: training_loss = 0.8054807076087183, Validation accuracy = 61.35
# Epoch 59: training_loss = 0.7325238667941493, Validation accuracy = 60.67
# Epoch 60: training_loss = 0.6398407841171536, Validation accuracy = 60.84
# Epoch 60: training_loss = 0.7829701637198514, Validation accuracy = 61.14
# Epoch 60: training_loss = 0.9056953368433136, Validation accuracy = 61.27
# Epoch 60: training_loss = 0.9314543241191394, Validation accuracy = 60.72
# Epoch 60: training_loss = 0.7674616232231162, Validation accuracy = 60.85
# Epoch 60: training_loss = 0.8045714417657226, Validation accuracy = 61.14
# Epoch 60: training_loss = 0.802457693262486, Validation accuracy = 61.45
# Epoch 60: training_loss = 0.7295319847985781, Validation accuracy = 60.65
# Epoch 61: training_loss = 0.636597638185976, Validation accuracy = 60.89
# Epoch 61: training_loss = 0.7794811722012815, Validation accuracy = 61.22
# Epoch 61: training_loss = 0.9015435715832801, Validation accuracy = 61.29
# Epoch 61: training_loss = 0.9261222554803686, Validation accuracy = 60.77
# Epoch 61: training_loss = 0.7632322719078344, Validation accuracy = 61.0
# Epoch 61: training_loss = 0.8004261468257294, Validation accuracy = 61.18
# Epoch 61: training_loss = 0.7995322992761131, Validation accuracy = 61.58
# Epoch 61: training_loss = 0.7266263746512263, Validation accuracy = 60.73
# Epoch 62: training_loss = 0.6334300073698459, Validation accuracy = 60.88
# Epoch 62: training_loss = 0.7760624487068375, Validation accuracy = 61.26
# Epoch 62: training_loss = 0.89751593181853, Validation accuracy = 61.29
# Epoch 62: training_loss = 0.9209463177447246, Validation accuracy = 60.88
# Epoch 62: training_loss = 0.7591245526344527, Validation accuracy = 61.05
# Epoch 62: training_loss = 0.7963818389969677, Validation accuracy = 61.27
# Epoch 62: training_loss = 0.7967004099879648, Validation accuracy = 61.59
# Epoch 62: training_loss = 0.7238030231230979, Validation accuracy = 60.74
# Epoch 63: training_loss = 0.6303353192504058, Validation accuracy = 60.91
# Epoch 63: training_loss = 0.7727114571159592, Validation accuracy = 61.27
# Epoch 63: training_loss = 0.8936071558420278, Validation accuracy = 61.37
# Epoch 63: training_loss = 0.9159211978843759, Validation accuracy = 60.97
# Epoch 63: training_loss = 0.7551338291435059, Validation accuracy = 61.14
# Epoch 63: training_loss = 0.7924346071016497, Validation accuracy = 61.32
# Epoch 63: training_loss = 0.7939580999594443, Validation accuracy = 61.68
# Epoch 63: training_loss = 0.721058124915873, Validation accuracy = 60.79
# Epoch 64: training_loss = 0.6273111445698247, Validation accuracy = 60.97
# Epoch 64: training_loss = 0.7694257971704553, Validation accuracy = 61.32
# Epoch 64: training_loss = 0.8898122546672795, Validation accuracy = 61.45
# Epoch 64: training_loss = 0.9110417653183103, Validation accuracy = 61.03
# Epoch 64: training_loss = 0.7512556669555505, Validation accuracy = 61.16
# Epoch 64: training_loss = 0.7885807424134278, Validation accuracy = 61.36
# Epoch 64: training_loss = 0.7913016244382612, Validation accuracy = 61.76
# Epoch 64: training_loss = 0.7183880711066444, Validation accuracy = 60.85
# Epoch 65: training_loss = 0.6243551835629976, Validation accuracy = 60.99
# Epoch 65: training_loss = 0.7662031957175455, Validation accuracy = 61.38
# Epoch 65: training_loss = 0.8861264936573456, Validation accuracy = 61.47
# Epoch 65: training_loss = 0.9063030607914212, Validation accuracy = 61.08
# Epoch 65: training_loss = 0.7474858227397067, Validation accuracy = 61.17
# Epoch 65: training_loss = 0.7848167267450286, Validation accuracy = 61.42
# Epoch 65: training_loss = 0.7887274103946978, Validation accuracy = 61.85
# Epoch 65: training_loss = 0.7157894384450294, Validation accuracy = 60.91
# Epoch 66: training_loss = 0.6214652540690723, Validation accuracy = 61.03
# Epoch 66: training_loss = 0.7630414986892778, Validation accuracy = 61.33
# Epoch 66: training_loss = 0.8825453757762367, Validation accuracy = 61.53
# Epoch 66: training_loss = 0.9017002866504814, Validation accuracy = 61.2
# Epoch 66: training_loss = 0.7438202344794945, Validation accuracy = 61.24
# Epoch 66: training_loss = 0.7811392211323057, Validation accuracy = 61.52
# Epoch 66: training_loss = 0.7862320480752115, Validation accuracy = 61.9
# Epoch 66: training_loss = 0.7132589794175968, Validation accuracy = 61.0
# Epoch 67: training_loss = 0.6186392811823684, Validation accuracy = 61.02
# Epoch 67: training_loss = 0.7599386637297029, Validation accuracy = 61.4
# Epoch 67: training_loss = 0.879064626303704, Validation accuracy = 61.61
# Epoch 67: training_loss = 0.8972287983665339, Validation accuracy = 61.19
# Epoch 67: training_loss = 0.7402550123616405, Validation accuracy = 61.33
# Epoch 67: training_loss = 0.7775450550957527, Validation accuracy = 61.61
# Epoch 67: training_loss = 0.7838122830254206, Validation accuracy = 61.91
# Epoch 67: training_loss = 0.7107936130029716, Validation accuracy = 61.03
# Epoch 68: training_loss = 0.6158752882328429, Validation accuracy = 61.06
# Epoch 68: training_loss = 0.7568927533929499, Validation accuracy = 61.37
# Epoch 68: training_loss = 0.8756801788703116, Validation accuracy = 61.65
# Epoch 68: training_loss = 0.8928840971642757, Validation accuracy = 61.19
# Epoch 68: training_loss = 0.7367864303195282, Validation accuracy = 61.44
# Epoch 68: training_loss = 0.7740312164641048, Validation accuracy = 61.57
# Epoch 68: training_loss = 0.7814650085415795, Validation accuracy = 62.07
# Epoch 68: training_loss = 0.7083904160482808, Validation accuracy = 60.99
# Epoch 69: training_loss = 0.613171388912551, Validation accuracy = 61.1
# Epoch 69: training_loss = 0.753901928845859, Validation accuracy = 61.38
# Epoch 69: training_loss = 0.8723881626837149, Validation accuracy = 61.69
# Epoch 69: training_loss = 0.8886618236286975, Validation accuracy = 61.27
# Epoch 69: training_loss = 0.7334109181685925, Validation accuracy = 61.45
# Epoch 69: training_loss = 0.77059484174664, Validation accuracy = 61.62
# Epoch 69: training_loss = 0.7791872585159365, Validation accuracy = 62.07
# Epoch 69: training_loss = 0.7060466152039586, Validation accuracy = 60.99
# Epoch 70: training_loss = 0.6105257803875349, Validation accuracy = 61.12
# Epoch 70: training_loss = 0.7509644440180253, Validation accuracy = 61.41
# Epoch 70: training_loss = 0.8691848908295339, Validation accuracy = 61.72
# Epoch 70: training_loss = 0.884557752167978, Validation accuracy = 61.3
# Epoch 70: training_loss = 0.7301250542762224, Validation accuracy = 61.47
# Epoch 70: training_loss = 0.7672332070415383, Validation accuracy = 61.68
# Epoch 70: training_loss = 0.7769762006468541, Validation accuracy = 62.11
# Epoch 70: training_loss = 0.7037595793598403, Validation accuracy = 60.98
# Epoch 71: training_loss = 0.6079367372548059, Validation accuracy = 61.16
# Epoch 71: training_loss = 0.748078640150306, Validation accuracy = 61.48
# Epoch 71: training_loss = 0.866066849541279, Validation accuracy = 61.7
# Epoch 71: training_loss = 0.8805677862198346, Validation accuracy = 61.29
# Epoch 71: training_loss = 0.7269255587137685, Validation accuracy = 61.47
# Epoch 71: training_loss = 0.7639437194675851, Validation accuracy = 61.75
# Epoch 71: training_loss = 0.7748291299893331, Validation accuracy = 62.12
# Epoch 71: training_loss = 0.7015268125310087, Validation accuracy = 60.95
# Epoch 72: training_loss = 0.605402606221933, Validation accuracy = 61.15
# Epoch 72: training_loss = 0.7452429407000565, Validation accuracy = 61.52
# Epoch 72: training_loss = 0.8630306883437217, Validation accuracy = 61.71
# Epoch 72: training_loss = 0.8766879540963621, Validation accuracy = 61.33
# Epoch 72: training_loss = 0.7238092868430032, Validation accuracy = 61.58
# Epoch 72: training_loss = 0.7607239091058369, Validation accuracy = 61.83
# Epoch 72: training_loss = 0.7727434628254207, Validation accuracy = 62.18
# Epoch 72: training_loss = 0.6993459471471531, Validation accuracy = 61.05
# Epoch 73: training_loss = 0.6029218014026296, Validation accuracy = 61.22
# Epoch 73: training_loss = 0.7424558465675938, Validation accuracy = 61.55
# Epoch 73: training_loss = 0.8600732109829973, Validation accuracy = 61.81
# Epoch 73: training_loss = 0.8729144053701638, Validation accuracy = 61.41
# Epoch 73: training_loss = 0.7207732232939396, Validation accuracy = 61.62
# Epoch 73: training_loss = 0.7575714214369146, Validation accuracy = 61.88
# Epoch 73: training_loss = 0.770716730837191, Validation accuracy = 62.26
# Epoch 73: training_loss = 0.6972147377042706, Validation accuracy = 60.99
# Epoch 74: training_loss = 0.6004928001358363, Validation accuracy = 61.31
# Epoch 74: training_loss = 0.7397159316138872, Validation accuracy = 61.55
# Epoch 74: training_loss = 0.8571913670648612, Validation accuracy = 61.89
# Epoch 74: training_loss = 0.8692434077122837, Validation accuracy = 61.45
# Epoch 74: training_loss = 0.7178144762952213, Validation accuracy = 61.66
# Epoch 74: training_loss = 0.7544840102583791, Validation accuracy = 61.88
# Epoch 74: training_loss = 0.7687465755673776, Validation accuracy = 62.26
# Epoch 74: training_loss = 0.6951310547423936, Validation accuracy = 61.01
# Epoch 75: training_loss = 0.5981141392484405, Validation accuracy = 61.33
# Epoch 75: training_loss = 0.737021838444054, Validation accuracy = 61.63
# Epoch 75: training_loss = 0.8543822443298642, Validation accuracy = 61.95
# Epoch 75: training_loss = 0.86567134410022, Validation accuracy = 61.45
# Epoch 75: training_loss = 0.7149302723223957, Validation accuracy = 61.72
# Epoch 75: training_loss = 0.7514595310654616, Validation accuracy = 61.94
# Epoch 75: training_loss = 0.7668307431546107, Validation accuracy = 62.29
# Epoch 75: training_loss = 0.6930928791176254, Validation accuracy = 60.99
# Epoch 76: training_loss = 0.5957844116930531, Validation accuracy = 61.3
# Epoch 76: training_loss = 0.7343722744352251, Validation accuracy = 61.66
# Epoch 76: training_loss = 0.8516430615010171, Validation accuracy = 62.0
# Epoch 76: training_loss = 0.8621947103221009, Validation accuracy = 61.5
# Epoch 76: training_loss = 0.7121179510332388, Validation accuracy = 61.71
# Epoch 76: training_loss = 0.7484959348771951, Validation accuracy = 61.92
# Epoch 76: training_loss = 0.7649670793314661, Validation accuracy = 62.3
# Epoch 76: training_loss = 0.6910982965411138, Validation accuracy = 60.98
# Epoch 77: training_loss = 0.5935022635023642, Validation accuracy = 61.33
# Epoch 77: training_loss = 0.7317660079905633, Validation accuracy = 61.66
# Epoch 77: training_loss = 0.8489711616457327, Validation accuracy = 61.93
# Epoch 77: training_loss = 0.8588101127108988, Validation accuracy = 61.5
# Epoch 77: training_loss = 0.7093749604629079, Validation accuracy = 61.78
# Epoch 77: training_loss = 0.7455912624889163, Validation accuracy = 61.92
# Epoch 77: training_loss = 0.7631535246744483, Validation accuracy = 62.33
# Epoch 77: training_loss = 0.6891454923616177, Validation accuracy = 60.95
# Epoch 78: training_loss = 0.5912663910106281, Validation accuracy = 61.36
# Epoch 78: training_loss = 0.7292018650039249, Validation accuracy = 61.67
# Epoch 78: training_loss = 0.8463640059996146, Validation accuracy = 61.98
# Epoch 78: training_loss = 0.8555142660502981, Validation accuracy = 61.49
# Epoch 78: training_loss = 0.7066988524550162, Validation accuracy = 61.76
# Epoch 78: training_loss = 0.7427436391311272, Validation accuracy = 61.9
# Epoch 78: training_loss = 0.7613881100955284, Validation accuracy = 62.32
# Epoch 78: training_loss = 0.6872327465720431, Validation accuracy = 60.98
# Epoch 79: training_loss = 0.5890755383008147, Validation accuracy = 61.41
# Epoch 79: training_loss = 0.7266787255218162, Validation accuracy = 61.7
# Epoch 79: training_loss = 0.8438191682050068, Validation accuracy = 61.98
# Epoch 79: training_loss = 0.8523039916014399, Validation accuracy = 61.48
# Epoch 79: training_loss = 0.7040872783078086, Validation accuracy = 61.78
# Epoch 79: training_loss = 0.7399512695139414, Validation accuracy = 61.93
# Epoch 79: training_loss = 0.7596689525652033, Validation accuracy = 62.4
# Epoch 79: training_loss = 0.6853584290236802, Validation accuracy = 60.98
# Epoch 80: training_loss = 0.5869284948430876, Validation accuracy = 61.43
# Epoch 80: training_loss = 0.7241955205910311, Validation accuracy = 61.75
# Epoch 80: training_loss = 0.8413343289221358, Validation accuracy = 62.01
# Epoch 80: training_loss = 0.8491762152071007, Validation accuracy = 61.57
# Epoch 80: training_loss = 0.7015379846173755, Validation accuracy = 61.78
# Epoch 80: training_loss = 0.7372124332357081, Validation accuracy = 61.9
# Epoch 80: training_loss = 0.7579942510571468, Validation accuracy = 62.41
# Epoch 80: training_loss = 0.683520994834875, Validation accuracy = 60.93
# Epoch 81: training_loss = 0.5848240932964129, Validation accuracy = 61.42
# Epoch 81: training_loss = 0.7217512292817179, Validation accuracy = 61.79
# Epoch 81: training_loss = 0.8389072707752632, Validation accuracy = 62.03
# Epoch 81: training_loss = 0.8461279654369406, Validation accuracy = 61.62
# Epoch 81: training_loss = 0.6990488093023385, Validation accuracy = 61.82
# Epoch 81: training_loss = 0.7345254805340494, Validation accuracy = 61.94
# Epoch 81: training_loss = 0.7563622827045988, Validation accuracy = 62.43
# Epoch 81: training_loss = 0.681718979983517, Validation accuracy = 61.04
# Epoch 82: training_loss = 0.5827612074505413, Validation accuracy = 61.41
# Epoch 82: training_loss = 0.7193448758767036, Validation accuracy = 61.81
# Epoch 82: training_loss = 0.8365358736004783, Validation accuracy = 62.09
# Epoch 82: training_loss = 0.8431563717440929, Validation accuracy = 61.65
# Epoch 82: training_loss = 0.6966176777966672, Validation accuracy = 61.88
# Epoch 82: training_loss = 0.7318888283573234, Validation accuracy = 61.98
# Epoch 82: training_loss = 0.7547713991586403, Validation accuracy = 62.53
# Epoch 82: training_loss = 0.6799509970749485, Validation accuracy = 61.09
# Epoch 83: training_loss = 0.5807387502901507, Validation accuracy = 61.4
# Epoch 83: training_loss = 0.7169755272187435, Validation accuracy = 61.78
# Epoch 83: training_loss = 0.8342181099655792, Validation accuracy = 62.11
# Epoch 83: training_loss = 0.8402586626095092, Validation accuracy = 61.67
# Epoch 83: training_loss = 0.694242599399199, Validation accuracy = 61.94
# Epoch 83: training_loss = 0.7293009567345924, Validation accuracy = 61.99
# Epoch 83: training_loss = 0.7532200231385082, Validation accuracy = 62.48
# Epoch 83: training_loss = 0.6782157312788342, Validation accuracy = 61.14
# Epoch 84: training_loss = 0.5787556721668394, Validation accuracy = 61.44
# Epoch 84: training_loss = 0.7146422902080031, Validation accuracy = 61.81
# Epoch 84: training_loss = 0.8319520409360674, Validation accuracy = 62.14
# Epoch 84: training_loss = 0.8374321636561539, Validation accuracy = 61.7
# Epoch 84: training_loss = 0.6919216637701563, Validation accuracy = 61.98
# Epoch 84: training_loss = 0.7267604054223682, Validation accuracy = 62.01
# Epoch 84: training_loss = 0.7517066451641551, Validation accuracy = 62.48
# Epoch 84: training_loss = 0.6765119364300144, Validation accuracy = 61.1
# Epoch 85: training_loss = 0.576810959067831, Validation accuracy = 61.46
# Epoch 85: training_loss = 0.712344309442635, Validation accuracy = 61.8
# Epoch 85: training_loss = 0.8297358120644356, Validation accuracy = 62.14
# Epoch 85: training_loss = 0.8346742957201927, Validation accuracy = 61.72
# Epoch 85: training_loss = 0.6896530375663693, Validation accuracy = 62.03
# Epoch 85: training_loss = 0.7242657708068632, Validation accuracy = 61.99
# Epoch 85: training_loss = 0.7502298204613376, Validation accuracy = 62.57
# Epoch 85: training_loss = 0.6748384312895922, Validation accuracy = 61.18
# Epoch 86: training_loss = 0.5749036309728615, Validation accuracy = 61.5
# Epoch 86: training_loss = 0.7100807649956923, Validation accuracy = 61.78
# Epoch 86: training_loss = 0.8275676495828378, Validation accuracy = 62.18
# Epoch 86: training_loss = 0.83198257287078, Validation accuracy = 61.7
# Epoch 86: training_loss = 0.687434961208168, Validation accuracy = 62.04
# Epoch 86: training_loss = 0.7218157030410748, Validation accuracy = 61.95
# Epoch 86: training_loss = 0.7487881660296665, Validation accuracy = 62.59
# Epoch 86: training_loss = 0.6731940959633466, Validation accuracy = 61.15
# Epoch 87: training_loss = 0.5730327402927198, Validation accuracy = 61.47
# Epoch 87: training_loss = 0.7078508703220052, Validation accuracy = 61.82
# Epoch 87: training_loss = 0.8254458567818058, Validation accuracy = 62.25
# Epoch 87: training_loss = 0.8293546003739481, Validation accuracy = 61.69
# Epoch 87: training_loss = 0.6852657457719037, Validation accuracy = 62.08
# Epoch 87: training_loss = 0.7194089033967859, Validation accuracy = 62.04
# Epoch 87: training_loss = 0.7473803578642384, Validation accuracy = 62.63
# Epoch 87: training_loss = 0.671577868475153, Validation accuracy = 61.22
# Epoch 88: training_loss = 0.5711973703845036, Validation accuracy = 61.45
# Epoch 88: training_loss = 0.7056538702889179, Validation accuracy = 61.83
# Epoch 88: training_loss = 0.8233688105599754, Validation accuracy = 62.24
# Epoch 88: training_loss = 0.8267880725993624, Validation accuracy = 61.67
# Epoch 88: training_loss = 0.6831437700029349, Validation accuracy = 62.05
# Epoch 88: training_loss = 0.7170441218125083, Validation accuracy = 62.01
# Epoch 88: training_loss = 0.7460051283217521, Validation accuracy = 62.6
# Epoch 88: training_loss = 0.6699887414934232, Validation accuracy = 61.23
# Epoch 89: training_loss = 0.5693966341397424, Validation accuracy = 61.43
# Epoch 89: training_loss = 0.7034890393250512, Validation accuracy = 61.84
# Epoch 89: training_loss = 0.8213349581318176, Validation accuracy = 62.25
# Epoch 89: training_loss = 0.8242807708714196, Validation accuracy = 61.68
# Epoch 89: training_loss = 0.6810674774445848, Validation accuracy = 62.05
# Epoch 89: training_loss = 0.7147201546193723, Validation accuracy = 62.04
# Epoch 89: training_loss = 0.7446612636222945, Validation accuracy = 62.59
# Epoch 89: training_loss = 0.6684257592086698, Validation accuracy = 61.27
# Epoch 90: training_loss = 0.5676296726423918, Validation accuracy = 61.38
# Epoch 90: training_loss = 0.7013556796814692, Validation accuracy = 61.85
# Epoch 90: training_loss = 0.8193428138821349, Validation accuracy = 62.29
# Epoch 90: training_loss = 0.8218305612683633, Validation accuracy = 61.68
# Epoch 90: training_loss = 0.6790353736791198, Validation accuracy = 62.05
# Epoch 90: training_loss = 0.7124358424281256, Validation accuracy = 62.08
# Epoch 90: training_loss = 0.743347601478354, Validation accuracy = 62.57
# Epoch 90: training_loss = 0.6668880143602364, Validation accuracy = 61.32
# Epoch 91: training_loss = 0.5658956538941812, Validation accuracy = 61.43
# Epoch 91: training_loss = 0.6992531197998397, Validation accuracy = 61.92
# Epoch 91: training_loss = 0.8173909563576374, Validation accuracy = 62.4
# Epoch 91: training_loss = 0.8194353923747562, Validation accuracy = 61.68
# Epoch 91: training_loss = 0.6770460236772397, Validation accuracy = 62.12
# Epoch 91: training_loss = 0.710190068161549, Validation accuracy = 62.06
# Epoch 91: training_loss = 0.742063028843005, Validation accuracy = 62.62
# Epoch 91: training_loss = 0.6653746454100297, Validation accuracy = 61.33
# Epoch 92: training_loss = 0.5641937716051256, Validation accuracy = 61.47
# Epoch 92: training_loss = 0.697180712782351, Validation accuracy = 61.84
# Epoch 92: training_loss = 0.81547802538723, Validation accuracy = 62.47
# Epoch 92: training_loss = 0.8170932929939262, Validation accuracy = 61.65
# Epoch 92: training_loss = 0.6750980492528703, Validation accuracy = 62.14
# Epoch 92: training_loss = 0.7079817552178193, Validation accuracy = 62.05
# Epoch 92: training_loss = 0.7408064797696337, Validation accuracy = 62.65
# Epoch 92: training_loss = 0.6638848338607616, Validation accuracy = 61.39
# Epoch 93: training_loss = 0.5625232440471628, Validation accuracy = 61.48
# Epoch 93: training_loss = 0.6951378349583058, Validation accuracy = 61.85
# Epoch 93: training_loss = 0.8136027193237768, Validation accuracy = 62.49
# Epoch 93: training_loss = 0.8148023698278507, Validation accuracy = 61.64
# Epoch 93: training_loss = 0.6731901266202887, Validation accuracy = 62.14
# Epoch 93: training_loss = 0.7058098657515833, Validation accuracy = 62.07
# Epoch 93: training_loss = 0.7395769333759986, Validation accuracy = 62.65
# Epoch 93: training_loss = 0.6624178017158683, Validation accuracy = 61.41
# Epoch 94: training_loss = 0.5608833129689047, Validation accuracy = 61.5
# Epoch 94: training_loss = 0.6931238845424805, Validation accuracy = 61.82
# Epoch 94: training_loss = 0.8117637924010509, Validation accuracy = 62.49
# Epoch 94: training_loss = 0.8125608051325034, Validation accuracy = 61.63
# Epoch 94: training_loss = 0.6713209840507672, Validation accuracy = 62.17
# Epoch 94: training_loss = 0.7036733990607112, Validation accuracy = 62.08
# Epoch 94: training_loss = 0.738373411905902, Validation accuracy = 62.65
# Epoch 94: training_loss = 0.6609728090778336, Validation accuracy = 61.45
# Epoch 95: training_loss = 0.5592732425694774, Validation accuracy = 61.54
# Epoch 95: training_loss = 0.6911382803804424, Validation accuracy = 61.84
# Epoch 95: training_loss = 0.8099600522003958, Validation accuracy = 62.47
# Epoch 95: training_loss = 0.8103668543569091, Validation accuracy = 61.65
# Epoch 95: training_loss = 0.6694893996260063, Validation accuracy = 62.16
# Epoch 95: training_loss = 0.7015713900678948, Validation accuracy = 62.11
# Epoch 95: training_loss = 0.7371949788821717, Validation accuracy = 62.67
# Epoch 95: training_loss = 0.659549151881267, Validation accuracy = 61.47
# Epoch 96: training_loss = 0.5576923185293226, Validation accuracy = 61.53
# Epoch 96: training_loss = 0.689180460776187, Validation accuracy = 61.86
# Epoch 96: training_loss = 0.8081903572222654, Validation accuracy = 62.49
# Epoch 96: training_loss = 0.808218843774207, Validation accuracy = 61.66
# Epoch 96: training_loss = 0.6676941990856884, Validation accuracy = 62.15
# Epoch 96: training_loss = 0.6995029078873976, Validation accuracy = 62.07
# Epoch 96: training_loss = 0.7360407373451326, Validation accuracy = 62.66
# Epoch 96: training_loss = 0.658146159756679, Validation accuracy = 61.49
# Epoch 97: training_loss = 0.5561398470957869, Validation accuracy = 61.5
# Epoch 97: training_loss = 0.687249882397536, Validation accuracy = 61.91
# Epoch 97: training_loss = 0.8064536145583512, Validation accuracy = 62.46
# Epoch 97: training_loss = 0.806115168112849, Validation accuracy = 61.67
# Epoch 97: training_loss = 0.6659342537664744, Validation accuracy = 62.13
# Epoch 97: training_loss = 0.6974670544683472, Validation accuracy = 62.11
# Epoch 97: training_loss = 0.7349098281711778, Validation accuracy = 62.61
# Epoch 97: training_loss = 0.6567631940205465, Validation accuracy = 61.5
# Epoch 98: training_loss = 0.554615154221192, Validation accuracy = 61.5
# Epoch 98: training_loss = 0.6853460192549008, Validation accuracy = 61.93
# Epoch 98: training_loss = 0.8047487776604518, Validation accuracy = 62.53
# Epoch 98: training_loss = 0.804054288195743, Validation accuracy = 61.67
# Epoch 98: training_loss = 0.6642084786297788, Validation accuracy = 62.18
# Epoch 98: training_loss = 0.6954629633069764, Validation accuracy = 62.08
# Epoch 98: training_loss = 0.7338014284664821, Validation accuracy = 62.68
# Epoch 98: training_loss = 0.6553996457869671, Validation accuracy = 61.52
# Epoch 99: training_loss = 0.553117584751045, Validation accuracy = 61.52
# Epoch 99: training_loss = 0.6834683617491105, Validation accuracy = 61.86
# Epoch 99: training_loss = 0.8030748442025737, Validation accuracy = 62.51
# Epoch 99: training_loss = 0.8020347285947439, Validation accuracy = 61.72
# Epoch 99: training_loss = 0.6625158303755846, Validation accuracy = 62.18
# Epoch 99: training_loss = 0.6934897982211714, Validation accuracy = 62.14
# Epoch 99: training_loss = 0.732714750031315, Validation accuracy = 62.67
# Epoch 99: training_loss = 0.6540549341959221, Validation accuracy = 61.51
# Epoch 100: training_loss = 0.5516465016599544, Validation accuracy = 61.54
# Epoch 100: training_loss = 0.6816164157841288, Validation accuracy = 61.84
# Epoch 100: training_loss = 0.8014308540330236, Validation accuracy = 62.5
# Epoch 100: training_loss = 0.8000550753073944, Validation accuracy = 61.76
# Epoch 100: training_loss = 0.6608553056395755, Validation accuracy = 62.15
# Epoch 100: training_loss = 0.6915467521815234, Validation accuracy = 62.23
# Epoch 100: training_loss = 0.7316490378907838, Validation accuracy = 62.71
# Epoch 100: training_loss = 0.6527285047530076, Validation accuracy = 61.52
